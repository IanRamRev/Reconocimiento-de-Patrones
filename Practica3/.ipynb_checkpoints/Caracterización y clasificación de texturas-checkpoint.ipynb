# %% [markdown]
# # Practica 3
# ## Actividad 1

# %%
import numpy as np
import cv2
from skimage import data, io, filters
from skimage.feature import greycomatrix, greycoprops

# %%
img = cv2.imread('.\\texturas\\D64.bmp')
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
io.imshow(img_gray)
print(img_gray.shape)
# Out:
# (640, 640)

# %% [markdown]
# Subdividimos la imagen en 4, 8 y 16 partes

# %%
ventana = np.vsplit(img_gray, 2)
V1 = np.hsplit(ventana[0], 2)
V2 = np.hsplit(ventana[1], 2)

# %%
image1 = np.array ([[4, 3, 3, 3, 1],
                   [4, 2, 2, 0, 1],
                   [4, 0, 0, 1, 1],
                   [0, 4, 4, 2, 2]], dtype=np.uint8)

# %%
#GLCM de oeste a este normalizada
result = greycomatrix(image, [1], [0],levels=5)
result[:, :, 0, 0]
# Out:
# array([[1, 2, 0, 0, 1],
#        [0, 1, 0, 0, 0],
#        [1, 0, 2, 0, 0],
#        [0, 1, 0, 2, 0],
#        [1, 0, 2, 1, 1]], dtype=uint32)

# %%
#GLCM de sur a norte normalizada
result = greycomatrix(image, [1], [-np.pi/2],levels=5)
result[:, :, 0, 0]
# Out:
# array([[0, 0, 2, 1, 1],
#        [1, 2, 0, 0, 0],
#        [0, 2, 0, 2, 0],
#        [0, 0, 0, 0, 0],
#        [2, 0, 0, 0, 2]], dtype=uint32)
