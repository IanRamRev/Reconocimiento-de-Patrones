# %% [markdown]
# # Ejercicios básicos

# %% [markdown]
# 1. Cargue los datos iris en un data frame (pandas) e imprima la forma de los datos, tipo y las 10 primeras filas de los datos

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

nombre_variables = ['longitud_sepalo', 'ancho_sepalo', 'longitud_petalo', 'ancho_petalo', 'clase']
iris = pd.read_csv('.\\Datos\\iris.csv')
irisName = pd.read_csv('.\\Datos\\iris.csv', names = nombre_variables)
print("Cabecera de los datos: \n", iris.head(10))
print("\nTipo de dato: ", type(iris))
# Out:
# Cabecera de los datos:
#     5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa
# 5  4.6  3.4  1.4  0.3  Iris-setosa
# 6  5.0  3.4  1.5  0.2  Iris-setosa
# 7  4.4  2.9  1.4  0.2  Iris-setosa
# 8  4.9  3.1  1.5  0.1  Iris-setosa
# 9  5.4  3.7  1.5  0.2  Iris-setosa
#
# Tipo de dato:  <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# 2. Imprima las llaves y el número de filas y de columnas.

# %%
irisName
# Out:
#      longitud_sepalo  ancho_sepalo  longitud_petalo  ancho_petalo  \
# 0                5.1           3.5              1.4           0.2
# 1                4.9           3.0              1.4           0.2
# 2                4.7           3.2              1.3           0.2
# 3                4.6           3.1              1.5           0.2
# 4                5.0           3.6              1.4           0.2
# ..               ...           ...              ...           ...
# 145              6.7           3.0              5.2           2.3
# 146              6.3           2.5              5.0           1.9
# 147              6.5           3.0              5.2           2.0
# 148              6.2           3.4              5.4           2.3
# 149              5.9           3.0              5.1           1.8
#
#               clase
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# ...

# %% [markdown]
# 3.  Obtenga el número de muestras faltantes o Nan

# %%
print("Elementos nulos: ", iris.isnull().values.sum())
# Out:
# Elementos nulos:  0

# %% [markdown]
# 4. Cree un arreglo 2-D de tamaño 5x5 con unos en la diagonal y ceros en el resto. Convierta el arreglo NumPy a una matriz dispersa de ScyPy en formato CRS

# %%
import scipy.sparse as sp
matrixA = np.identity(5)
matrixDispersa = sp.csr_matrix(matrixA)
print(matrixDispersa)
# Out:
#   (0, 0)	1.0
#   (1, 1)	1.0
#   (2, 2)	1.0
#   (3, 3)	1.0
#   (4, 4)	1.0

# %% [markdown]
# 5. Muestre estadísticas básicas como percentil, media, mínimo, máximo y desviación estándar de los datos. Use describe para ello. Imprima sólo la media y la desviación estándar.

# %%
print("Media: \n", irisName.mean())
print("\nDesviación estándar: \n", irisName.std())
# Out:
# Media:
#  longitud_sepalo    5.843333
# ancho_sepalo       3.054000
# longitud_petalo    3.758667
# ancho_petalo       1.198667
# dtype: float64
#
# Desviación estándar:
#  longitud_sepalo    0.828066
# ancho_sepalo       0.433594
# longitud_petalo    1.764420
# ancho_petalo       0.763161
# dtype: float64

# %% [markdown]
# 6. Obtenga el número de muestras para cada clase. (Pendiente)

# %%
clasesIris = irisName.groupby('clase')['clase'].count()
clasesIris
# Out:
# clase
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: clase, dtype: int64

# %% [markdown]
# 7. Añada un encabezado a los datos usando los nombres en iris.names y repita el ejercicio anterior

# %%
clasesIris = irisName.groupby('clase')['clase'].count()
clasesIris
# Out:
# clase
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: clase, dtype: int64

# %% [markdown]
# 8. Imprima las diez primeras filas y las dos primeras columnas del data frame usando los índices de las columnas.

# %%
irisName.iloc[:10,:2]
# Out:
#    longitud_sepalo  ancho_sepalo
# 0              5.1           3.5
# 1              4.9           3.0
# 2              4.7           3.2
# 3              4.6           3.1
# 4              5.0           3.6
# 5              5.4           3.9
# 6              4.6           3.4
# 7              5.0           3.4
# 8              4.4           2.9
# 9              4.9           3.1

# %% [markdown]
# # Ejercicio de visualización

# %% [markdown]
# 1. Cree una gráfica de barras que muestre la media, mínimo y máximo de todos los datos.

# %%
from seaborn import lmplot

media = irisName.describe().mean()
print(media)
minimo = irisName.describe().min()
print(minimo)
maximo = irisName.describe().max()
print(maximo)

irisName.describe()
#lmplot('total_bill', 'tip', data=tips, fit_reg=False)
# Out:
# longitud_sepalo    23.271425
# ancho_sepalo       21.123449
# longitud_petalo    21.809136
# ancho_petalo       19.745228
# dtype: float64
# longitud_sepalo    0.828066
# ancho_sepalo       0.433594
# longitud_petalo    1.000000
# ancho_petalo       0.100000
# dtype: float64
# longitud_sepalo    150.0
# ancho_sepalo       150.0
# longitud_petalo    150.0
# ancho_petalo       150.0
# dtype: float64
#        longitud_sepalo  ancho_sepalo  longitud_petalo  ancho_petalo
# count       150.000000    150.000000       150.000000    150.000000
# mean          5.843333      3.054000         3.758667      1.198667
# std           0.828066      0.433594         1.764420      0.763161
# min           4.300000      2.000000         1.000000      0.100000
# 25%           5.100000      2.800000         1.600000      0.300000
# 50%           5.800000      3.000000         4.350000      1.300000
# 75%           6.400000      3.300000         5.100000      1.800000
# ...

# %% [markdown]
# 2. Muestre la frecuencia de las tres especies como una gráfica de pastel

# %%
labels = 'Iris-setosa', 'Iris-versicolor', 'Iris-virginica'
fig1, ax1 = plt.subplots()
explode = (0.1, 0.1, 0.1)
ax1.pie(clasesIris, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)

ax1.axis('equal') 
plt.show()

# %% [markdown]
# 3. Cree una gráfica que muestre la relación entre la longitud y ancho del sépalo de las tres especies conjuntamente

# %%
sns.set()
#graphSNS = sns.load_dataset(irisName)
grafica = sns.lmplot(x="longitud_sepalo", y="ancho_sepalo", hue="clase",
               height=5, data=irisName)

grafica.set_axis_labels("Longitud sepalo (mm)", "Anchura sepalo (mm)")

# %% [markdown]
# 4. Obtenga los histogramas de las variables SepalLength, SepalWidth, PetalLength y PetalWidth.

# %%
sns.set(style="white", palette="muted", color_codes=True)
f, axes = plt.subplots(2, 2, figsize=(7, 7), sharex=True)

sns.distplot(irisName['longitud_sepalo'], kde=False, color="b", ax=axes[0, 0])
sns.distplot(irisName['ancho_sepalo'], hist=False, rug=True, color="r", ax=axes[0, 1])
sns.distplot(irisName['longitud_petalo'], hist=False, color="g", kde_kws={"shade": True}, ax=axes[1, 0])
sns.distplot(irisName['ancho_petalo'], color="m", ax=axes[1, 1])

plt.setp(axes, yticks=[])
plt.tight_layout()

# %% [markdown]
# 5. Cree gráficas de dispersión usando pairplot de seaborn y muestre con distintos colores las tres especies en las gráficas de dispersión

# %%
sns.set(style="ticks")

sns.pairplot(irisName, hue="clase", palette="husl")

# %% [markdown]
# 6. Cree una gráfica usando joinplot de seaborn para mostrar la dispersión entre la longitud y ancho del sépalo y las distribuciones de estas dos variables
