# %%
from skimage import data, io
import matplotlib.pyplot as plt
import cv2

img = cv2.imread(".\\Imagenes\\peppers_color.tif", cv2.IMREAD_GRAYSCALE)
#io.imshow(img)

# 4.4.1 just one pepper
# (x1, y1, x2, y2)
cropped_img = img[200:500, 174:430]
io.imshow(cropped_img)

# 4.4.2 save as PNG
cv2.imwrite(".\\Imagenes\\pepper_gray.png", cropped_img)
# Out:
# True
