# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import data, io
import cv2
# %matplotlib inline



def openImage(path):
    img = cv2.imread(path)
    return img

def convertChannelOpenCV(img, channelType):
    if(channelType == 1):
        imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        return imgRGB
    if(channelType == 2):
        img_gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
        return img_gray
    if(channelType == 3):
        img_yuv = cv2.cvtColor(img, cv2.COLOR_BGR2YUV)
        return img_yuv
    if(channelType == 4):
        img_hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
        return img_hsv
        
        


#image path´s
pathLena = '.\\Imagenes\\lena_color_512.tif'
pathPeppers = '.\\Imagenes\\peppers_color.tif'

# %%
#Convert RGB
io.imshow(convertChannelOpenCV(openImage(pathLena), 1))

# %%
#Convert RGB
io.imshow(convertChannelOpenCV(openImage(pathPeppers), 1))

# %%
#Convert RGB to gray scale
io.imshow(convertChannelOpenCV(openImage(pathLena), 2))

# %%
#Convert RGB to gray scale
io.imshow(convertChannelOpenCV(openImage(pathPeppers), 2))

# %%
#Convert RGB to YUV
io.imshow(convertChannelOpenCV(openImage(pathLena), 3))

# %%
#Convert RGB to YUV
io.imshow(convertChannelOpenCV(openImage(pathPeppers), 3))

# %%
#Convert RGB to HSV
io.imshow(convertChannelOpenCV(openImage(pathLena), 4))

# %%
#RGB a HSV
img_hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
io.imshow(img_hsv)

# %%
#RGB a HSV
img_hsv2 = cv2.cvtColor(img2, cv2.COLOR_BGR2HSV)
io.imshow(img_hsv2)

# %%
imgR = imgRGB.copy()

imgR[:,:,0] = 0 
imgR[:,:,1] = 0 

plt.title("Lena Rojo")
plt.imshow(cv2.cvtColor(imgR, cv2.COLOR_BGR2RGB))

# %%
imgR2 = imgRGB2.copy()

imgR2[:,:,0] = 0 
imgR2[:,:,1] = 0 

plt.title("Pimiento Rojo")
plt.imshow(cv2.cvtColor(imgR2, cv2.COLOR_BGR2RGB))

# %%
imgG = imgRGB.copy()

imgG[:,:,0] = 0 
imgG[:,:,2] = 0 
plt.title("Lena verde")
plt.imshow(cv2.cvtColor(imgG, cv2.COLOR_BGR2RGB))

# %%
imgG2 = imgRGB2.copy()

imgG2[:,:,0] = 0 
imgG2[:,:,2] = 0 
plt.title("Pimiento verde")
plt.imshow(cv2.cvtColor(imgG2, cv2.COLOR_BGR2RGB))

# %%
imgB = imgRGB.copy()

imgB[:,:,1] = 0 
imgB[:,:,2] = 0 
plt.title("Lena Azul")
plt.imshow(cv2.cvtColor(imgB, cv2.COLOR_BGR2RGB))
plt.show()

# %%
imgB2 = imgRGB2.copy()

imgB2[:,:,1] = 0 
imgB2[:,:,2] = 0 
plt.title("Pimiento Azul")
plt.imshow(cv2.cvtColor(imgB2, cv2.COLOR_BGR2RGB))
plt.show()

# %%
#Despliega la paleta de colores HSV por separado
imgHSV = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
h, s, v = cv2.split(imgHSV)
s.fill(255)
v.fill(255)

out = cv2.cvtColor(imgHSV, cv2.COLOR_HSV2BGR)

cv2.imshow('example', out)
cv2.waitKey()

# %%
imgSCIKIT = io.imread('.\\Imagenes\\lena_color_512.tif')
io.imshow(imgSCIKIT)

# %%
#RGB a YUV
from skimage.color import rgb2yuv
yuv_img = rgb2yuv(imgSCIKIT)
#io.imshow(yuv_img)
io.imshow(yuv_img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
#RGB a HSV
from skimage.color import rgb2hsv
hsv_img = rgb2hsv(imgSCIKIT)
io.imshow(hsv_img)

# %%
#RGB a escala de grises
from skimage.color import rgb2grey
gray_img = rgb2grey(imgSCIKIT)
io.imshow(gray_img)
