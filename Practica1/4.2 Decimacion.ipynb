# %%
#SCRIPT PARA ABRIR IMAGEN CON SCIKIT
#https://scikit-image.org/docs/stable/api/skimage.io.html#skimage.io.plugin_info
from skimage import data, io
from skimage.color import rgb2grey
import numpy as np
import pandas as pd

img = io.imread('.\\Imagenes\\lena_color_512.tif')
gray_img = rgb2grey(img)
io.imshow(gray_img)
print(gray_img)
print(gray_img.shape)
print(len(gray_img))
# Out:
# [[0.60802863 0.60802863 0.60779059 ... 0.64137412 0.57998235 0.46985725]
#  [0.60802863 0.60802863 0.60779059 ... 0.64137412 0.57998235 0.46985725]
#  [0.60802863 0.60802863 0.60779059 ... 0.64137412 0.57998235 0.46985725]
#  ...
#  [0.13746353 0.13746353 0.16881412 ... 0.37271804 0.35559529 0.34377725]
#  [0.14617059 0.14617059 0.18730588 ... 0.36788784 0.37292549 0.38467529]
#  [0.14617059 0.14617059 0.18730588 ... 0.36788784 0.37292549 0.38467529]]
# (512, 512)
# 512

# %%
newArray = np.array([])
imgPlana = gray_img.flatten()
print('Pixeles: ', len(imgPlana))

#Dividimos la primer columna en subarrays de 4 elementos. Cada pixel tiene 1 componente al ser escala de grises
arraySegmentado = np.split(imgPlana, 65536) #Segmenta la fila en 65536 arreglos (4 elementos cada subarreglos)
print(arraySegmentado)
print('No. de arrays de 4 elementos: ', len(arraySegmentado))


for i in range(len(arraySegmentado)): # Elementos de filas
    promedio = arraySegmentado[i].mean() #Promedio
    newArray = np.append(promedio, newArray)
            

arrayFinal = np.reshape(newArray, (256,256))
#print(newArray)
print('Tamaño: ', newArray.shape)
#print(newArray)
# Out:
# Pixeles:  262144
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-136-5343519901ce> in <module>
#      10
#      11 for i in range(len(imgPlana)): # Elementos de filas
# ---> 12     promedio = arraySegmentado[i].mean()
#      13     newArray = np.append(promedio, newArray)
#      14
#
# IndexError: list index out of range

# %%
#Ahora vamos a mostrar la imagen 
import matplotlib.pyplot as plt
plt.rcParams['image.cmap'] = 'gray'
# %matplotlib inline

plt.imshow(arrayFinal,vmin=0,vmax=1)
