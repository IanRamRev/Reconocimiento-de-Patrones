# %%
from matplotlib import pyplot as plt
from PIL import Image

# Reading bytes from RAW file
image= open('Imagenes/rosa800x600.raw', 'rb').read()
# Parsing from bytearray to 200x800 RGB image 
img = Image.frombytes('RGB', (200,600), image)
#showing
plt.imshow(img)
plt.show()
