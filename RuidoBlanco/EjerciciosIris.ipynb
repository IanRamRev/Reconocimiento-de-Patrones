# %% [markdown]
# # Ejercicios básicos

# %% [markdown]
# 1. Cargue los datos iris en un data frame (pandas) e imprima la forma de los datos, tipo y las 10 primeras filas de los datos

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from seaborn import lmplot

nombre_variables = ['longitud_sepalo', 'ancho_sepalo', 'longitud_petalo', 'ancho_petalo', 'clase']
iris = pd.read_csv('.\\Datos\\iris.csv')
irisName = pd.read_csv('.\\Datos\\iris.csv', names = nombre_variables)
print("Cabecera de los datos: \n", iris.head(10))
print("\nTipo de dato: ", type(iris))
# Out:
# Cabecera de los datos:
#     5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa
# 5  4.6  3.4  1.4  0.3  Iris-setosa
# 6  5.0  3.4  1.5  0.2  Iris-setosa
# 7  4.4  2.9  1.4  0.2  Iris-setosa
# 8  4.9  3.1  1.5  0.1  Iris-setosa
# 9  5.4  3.7  1.5  0.2  Iris-setosa
#
# Tipo de dato:  <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# 2. Imprima las llaves y el número de filas y de columnas.

# %%
irisName
# Out:
#      longitud_sepalo  ancho_sepalo  longitud_petalo  ancho_petalo  \
# 0                5.1           3.5              1.4           0.2
# 1                4.9           3.0              1.4           0.2
# 2                4.7           3.2              1.3           0.2
# 3                4.6           3.1              1.5           0.2
# 4                5.0           3.6              1.4           0.2
# ..               ...           ...              ...           ...
# 145              6.7           3.0              5.2           2.3
# 146              6.3           2.5              5.0           1.9
# 147              6.5           3.0              5.2           2.0
# 148              6.2           3.4              5.4           2.3
# 149              5.9           3.0              5.1           1.8
#
#               clase
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# ...

# %% [markdown]
# 3.  Obtenga el número de muestras faltantes o Nan

# %%
print("Elementos nulos: ", iris.isnull().values.sum())
# Out:
# Elementos nulos:  0

# %% [markdown]
# 4. Cree un arreglo 2-D de tamaño 5x5 con unos en la diagonal y ceros en el resto. Convierta el arreglo NumPy a una matriz dispersa de ScyPy en formato CRS

# %%
import scipy.sparse as sp
matrixA = np.identity(5)
matrixDispersa = sp.csr_matrix(matrixA)
print(matrixDispersa)
# Out:
#   (0, 0)	1.0
#   (1, 1)	1.0
#   (2, 2)	1.0
#   (3, 3)	1.0
#   (4, 4)	1.0

# %% [markdown]
# 5. Muestre estadísticas básicas como percentil, media, mínimo, máximo y desviación estándar de los datos. Use describe para ello. Imprima sólo la media y la desviación estándar.

# %%
irisName.describe()
# Out:
#        longitud_sepalo  ancho_sepalo  longitud_petalo  ancho_petalo
# count       150.000000    150.000000       150.000000    150.000000
# mean          5.843333      3.054000         3.758667      1.198667
# std           0.828066      0.433594         1.764420      0.763161
# min           4.300000      2.000000         1.000000      0.100000
# 25%           5.100000      2.800000         1.600000      0.300000
# 50%           5.800000      3.000000         4.350000      1.300000
# 75%           6.400000      3.300000         5.100000      1.800000
# max           7.900000      4.400000         6.900000      2.500000

# %%
print("\nMedia: \n", irisName.mean())
print("\nDesviación estándar: \n", irisName.std())
# Out:
# Media:
#  longitud_sepalo    5.843333
# ancho_sepalo       3.054000
# longitud_petalo    3.758667
# ancho_petalo       1.198667
# dtype: float64
#
# Desviación estándar:
#  longitud_sepalo    0.828066
# ancho_sepalo       0.433594
# longitud_petalo    1.764420
# ancho_petalo       0.763161
# dtype: float64

# %% [markdown]
# 6. Obtenga el número de muestras para cada clase. (Pendiente)

# %%
clasesIris = irisName.groupby('clase')['clase'].count()
clasesIris
# Out:
# clase
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: clase, dtype: int64

# %% [markdown]
# 7. Añada un encabezado a los datos usando los nombres en iris.names y repita el ejercicio anterior

# %%
clasesIris = irisName.groupby('clase')['clase'].count()
clasesIris
# Out:
# clase
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: clase, dtype: int64

# %% [markdown]
# 8. Imprima las diez primeras filas y las dos primeras columnas del data frame usando los índices de las columnas.

# %%
irisName.iloc[:10,:2]
# Out:
#    longitud_sepalo  ancho_sepalo
# 0              5.1           3.5
# 1              4.9           3.0
# 2              4.7           3.2
# 3              4.6           3.1
# 4              5.0           3.6
# 5              5.4           3.9
# 6              4.6           3.4
# 7              5.0           3.4
# 8              4.4           2.9
# 9              4.9           3.1

# %% [markdown]
# # Ejercicio de visualización

# %% [markdown]
# 1. Cree una gráfica de barras que muestre la media, mínimo y máximo de todos los datos.

# %%
X = np.array(irisName['longitud_sepalo'])
Y = np.array(irisName['ancho_sepalo'])
W = np.array(irisName['longitud_petalo'])
Z = np.array(irisName['ancho_petalo'])

minX = X.min()
minY = Y.min()
minW = W.min()
minZ = Z.min()
maxX = X.max()
maxY = Y.max()
maxW = W.max()
maxZ = Z.max()

mediaX = X.mean()
mediaY = Y.mean()
mediaW = W.mean()
mediaZ = Z.mean()

# %%
datosMin = np.array([minX,minY,minW,minZ])
ax = sns.barplot(x=datosMin,y=datosMin,data=irisName)

# %%
datosMax = np.array([maxX,maxY,maxW,maxZ])
ay = sns.barplot(x=datosMax,y=datosMax,data=irisName)

# %%
media = np.array([mediaX,mediaY,mediaW,mediaZ])
aw = sns.barplot(x=media,y=media,data=irisName)

# %% [markdown]
# 2. Muestre la frecuencia de las tres especies como una gráfica de pastel

# %%
labels = 'Iris-setosa', 'Iris-versicolor', 'Iris-virginica'
fig1, ax1 = plt.subplots()
explode = (0.1, 0.1, 0.1)
ax1.pie(clasesIris, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)

ax1.axis('equal') 
plt.show()

# %% [markdown]
# 3. Cree una gráfica que muestre la relación entre la longitud y ancho del sépalo de las tres especies conjuntamente

# %%
sns.set()
#graphSNS = sns.load_dataset(irisName)
grafica = sns.lmplot(x="longitud_sepalo", y="ancho_sepalo", hue="clase",
               height=5, data=irisName)

grafica.set_axis_labels("Longitud sepalo (mm)", "Anchura sepalo (mm)")

# %% [markdown]
# 4. Obtenga los histogramas de las variables SepalLength, SepalWidth, PetalLength y PetalWidth.

# %%
sns.set(style="white", palette="muted", color_codes=True)
f, axes = plt.subplots(2, 2, figsize=(7, 7), sharex=True)

sns.distplot(irisName['longitud_sepalo'], kde=False, color="b", ax=axes[0, 0])
sns.distplot(irisName['ancho_sepalo'], hist=False, rug=True, color="r", ax=axes[0, 1])
sns.distplot(irisName['longitud_petalo'], hist=False, color="g", kde_kws={"shade": True}, ax=axes[1, 0])
sns.distplot(irisName['ancho_petalo'], color="m", ax=axes[1, 1])

plt.setp(axes, yticks=[])
plt.tight_layout()

# %% [markdown]
# 5. Cree gráficas de dispersión usando pairplot de seaborn y muestre con distintos colores las tres especies en las gráficas de dispersión

# %%
sns.set(style="ticks")
sns.pairplot(irisName, hue="clase", palette="husl")

# %% [markdown]
# 6. Cree una gráfica usando joinplot de seaborn para mostrar la dispersión entre la longitud y ancho del sépalo y las distribuciones de estas dos variables

# %%
sns.set(style="ticks")
sns.jointplot(irisName["longitud_sepalo"], irisName["longitud_petalo"], color="#14db64")

# %% [markdown]
# 7. Repita el ejercicio anterior, pero esta vez usando joinplot con kind="hexbin" (pendiente)

# %%
sns.set(style="ticks")
sns.jointplot(irisName["longitud_sepalo"], irisName["longitud_petalo"], kind="hexbin", color="#14db64")

# %% [markdown]
# # Ejercicios de regresión logística

# %% [markdown]
# 1. Muestre los percentiles, media y desviación estándar de cada especie ('Iris-setosa', 'Irisversicolor' e 'Iris- virginica')

# %%
print("Desviación estándar: \n", irisName[irisName['clase'] == 'Iris-setosa'].std())
print("\nMedia: \n", irisName[irisName['clase'] == 'Iris-setosa'].mean())
print("\nPercentil 25%: \n", irisName[irisName['clase'] == 'Iris-setosa'].describe().iloc[4,:4])
print("\nPercentil 50%: \n", irisName[irisName['clase'] == 'Iris-setosa'].describe().iloc[5,:4])
print("\nPercentil 75%: \n", irisName[irisName['clase'] == 'Iris-setosa'].describe().iloc[6,:4])
# Out:
# Desviación estándar:
#  longitud_sepalo    0.352490
# ancho_sepalo       0.381024
# longitud_petalo    0.173511
# ancho_petalo       0.107210
# dtype: float64
#
# Media:
#  longitud_sepalo    5.006
# ancho_sepalo       3.418
# longitud_petalo    1.464
# ancho_petalo       0.244
# dtype: float64
#
# Percentil 25%:
#  longitud_sepalo    4.800
# ancho_sepalo       3.125
# longitud_petalo    1.400
# ancho_petalo       0.200
# Name: 25%, dtype: float64
#
# Percentil 50%:
#  longitud_sepalo    5.0
# ancho_sepalo       3.4
# longitud_petalo    1.5
# ancho_petalo       0.2
# Name: 50%, dtype: float64
#
# Percentil 75%:
#  longitud_sepalo    5.200
# ancho_sepalo       3.675
# longitud_petalo    1.575
# ancho_petalo       0.300
# Name: 75%, dtype: float64

# %%
print("Desviación estándar: \n", irisName[irisName['clase'] == 'Iris-versicolor'].std())
print("\nMedia: \n", irisName[irisName['clase'] == 'Iris-setosa'].mean())
print("\nPercentil 25%: \n", irisName[irisName['clase'] == 'Iris-versicolor'].describe().iloc[4,:4])
print("\nPercentil 50%: \n", irisName[irisName['clase'] == 'Iris-versicolor'].describe().iloc[5,:4])
print("\nPercentil 75%: \n", irisName[irisName['clase'] == 'Iris-versicolor'].describe().iloc[6,:4])
# Out:
# Desviación estándar:
#  longitud_sepalo    0.516171
# ancho_sepalo       0.313798
# longitud_petalo    0.469911
# ancho_petalo       0.197753
# dtype: float64
#
# Media:
#  longitud_sepalo    5.006
# ancho_sepalo       3.418
# longitud_petalo    1.464
# ancho_petalo       0.244
# dtype: float64
#
# Percentil 25%:
#  longitud_sepalo    5.600
# ancho_sepalo       2.525
# longitud_petalo    4.000
# ancho_petalo       1.200
# Name: 25%, dtype: float64
#
# Percentil 50%:
#  longitud_sepalo    5.90
# ancho_sepalo       2.80
# longitud_petalo    4.35
# ancho_petalo       1.30
# Name: 50%, dtype: float64
#
# Percentil 75%:
#  longitud_sepalo    6.3
# ancho_sepalo       3.0
# longitud_petalo    4.6
# ancho_petalo       1.5
# Name: 75%, dtype: float64

# %%
print("Desviación estándar: \n", irisName[irisName['clase'] == 'Iris-virginica'].std())
print("\nMedia: \n", irisName[irisName['clase'] == 'Iris-virginica'].mean())
print("\nPercentil 25%: \n", irisName[irisName['clase'] == 'Iris-virginica'].describe().iloc[4,:4])
print("\nPercentil 50%: \n", irisName[irisName['clase'] == 'Iris-virginica'].describe().iloc[5,:4])
print("\nPercentil 75%: \n", irisName[irisName['clase'] == 'Iris-virginica'].describe().iloc[6,:4])
# Out:
# Desviación estándar:
#  longitud_sepalo    0.635880
# ancho_sepalo       0.322497
# longitud_petalo    0.551895
# ancho_petalo       0.274650
# dtype: float64
#
# Media:
#  longitud_sepalo    6.588
# ancho_sepalo       2.974
# longitud_petalo    5.552
# ancho_petalo       2.026
# dtype: float64
#
# Percentil 25%:
#  longitud_sepalo    6.225
# ancho_sepalo       2.800
# longitud_petalo    5.100
# ancho_petalo       1.800
# Name: 25%, dtype: float64
#
# Percentil 50%:
#  longitud_sepalo    6.50
# ancho_sepalo       3.00
# longitud_petalo    5.55
# ancho_petalo       2.00
# Name: 50%, dtype: float64
#
# Percentil 75%:
#  longitud_sepalo    6.900
# ancho_sepalo       3.175
# longitud_petalo    5.875
# ancho_petalo       2.300
# Name: 75%, dtype: float64

# %% [markdown]
# 2. Cree una gráfica de dispersión de la longitud del sépalo y ancho del pétalo mostrando en la gráfica las tres especies con distintos colores.

# %%
sns.set(style="ticks")
sns.pairplot(irisName, hue="clase", palette="husl", vars=["longitud_sepalo", "ancho_sepalo"])
#g = sns.pairplot(iris, vars=["sepal_width", "sepal_length"])

# %% [markdown]
# 3. En el modelado estadístico, el análisis de regresión es un proceso para estimar la relación entre variables. Investigue y describa la regresión logística.

# %% [markdown]
# Se dice que un proceso es binomial cuando sólo tiene dos posibles resultados: "éxito" y "fracaso", siendo la probabilidad de cada uno de ellos constante en una serie de repeticiones. A la variable número de éxitos en n repeticiones se le denomina variable binomial.
#
# Un proceso binomial está caracterizado por la probabilidad de éxito, representada por p (es el único parámetro de su función de probabilidad), la probabilidad de fracaso se representa por q y, evidentemente, ambas probabilidades están relacionadas por p+q=1.
#
# Los modelos de regresión logística son modelos de regresión que permiten estudiar si una variable binomial depende, o no, de otra u otras variables (no necesariamente binomiales): Si una variable binomial de parámetro p es independiente de otra variable X, se cumple p=p|X, por consiguiente, un modelo de regresión es una función de p en X que a través del coeficiente de X permite investigar la relación anterior.
#
# La Regresión Logística Simple, desarrollada por David Cox en 1958, es un método de regresión que permite estimar la probabilidad de una variable cualitativa binaria en función de una variable cuantitativa. Una de las principales aplicaciones de la regresión logística es la de clasificación binaria, en el que las observaciones se clasifican en un grupo u otro dependiendo del valor que tome la variable empleada como predictor

# %%
X = np.array(irisName.drop(['clase'],1))
y = np.array(irisName['clase'])
X.shape
# Out:
# (150, 4)

# %%
from sklearn import linear_model
from sklearn import model_selection
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

model = linear_model.LogisticRegression()
model.fit(X,y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
#Predicción de prueba
predictions = model.predict(X)
print(predictions)

#Medimos la precisión media de las predicciones
print(model.score(X,y)) #07%
# Out:
# ['Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
# ...
